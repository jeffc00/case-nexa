# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, TimeSeriesSplit, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
import scipy.stats as ss

# %%
pd.options.display.max_columns = 50

# %%
summary = pd.read_csv('data/summary.csv')
day1 = pd.read_csv('data/day 1.csv')

# %%
summary.describe()
# Out:
#         Unnamed: 0  arrival_time  assessment_end_time  assessment_start_time  \
# count  4420.000000   4420.000000          4420.000000            4420.000000
# mean   2209.500000   7266.919005          8046.609729            7926.587557
# std    1276.088424   4146.204964          4449.402028            4448.635840
# min       0.000000      0.000000           113.000000              18.000000
# 25%    1104.750000   3774.500000          4297.750000            4188.500000
# 50%    2209.500000   7229.500000          7992.500000            7871.500000
# 75%    3314.250000  10914.250000         11816.750000           11692.000000
# max    4419.000000  14399.000000         18324.000000           18164.000000
#
#        consultation_end_time  consultation_start_time          day  \
# count            4420.000000              4420.000000  4420.000000
# mean             8721.045475              8092.128281    26.843665
# std              4443.100402              4449.621981    14.278000
# min               574.000000               137.000000     1.000000
# 25%              4952.250000              4343.250000    15.000000
# 50%              8721.000000              8072.500000    27.000000
# 75%             12448.750000             11867.000000    39.000000
# max             19202.000000             18350.000000    50.000000
#
#           duration      patient  temperature
# count  4420.000000  4420.000000  4420.000000
# mean    628.414706  2210.500000    36.872330
# std     466.094118  1276.088424     0.452982
# min      81.000000     1.000000    35.900000
# 25%     337.000000  1105.750000    36.700000
# 50%     490.000000  2210.500000    36.800000
# 75%     774.250000  3315.250000    36.925000
# max    4833.000000  4420.000000    42.600000

# %%
day1.head(20)
# Out:
#     Unnamed: 0                             assessment  day  \
# 0            0                                    NaN    1
# 1            1                                    NaN    1
# 2            2                                    NaN    1
# 3            3                                    NaN    1
# 4            4      urgent|36.599999999999994|no pain    1
# 5            5                                    NaN    1
# 6            6                                    NaN    1
# 7            7  normal|36.699999999999996|severe pain    1
# 8            8                                    NaN    1
# 9            9                                    NaN    1
# 10          10                                    NaN    1
# 11          11                normal|36.8|severe pain    1
# 12          12                                    NaN    1
# 13          13                                    NaN    1
# 14          14                                    NaN    1
# 15          15  urgent|36.599999999999994|severe pain    1
# 16          16                                    NaN    1
# 17          17                                    NaN    1
# 18          18  urgent|36.199999999999996|severe pain    1
# 19          19                                    NaN    1
#
#                      event  patient  time
# 0                  arrived        1   280
# 1                  arrived        2   288
# 2     assessment initiated        1   308
# 3                  arrived        3   430
# 4     assessment concluded        1   741
# 5     assessment initiated        2   764
# 6   consultation_initiated        1   773
# 7     assessment concluded        2   851
# 8     assessment initiated        3   878
# 9   consultation_initiated        2   905
# 10                 arrived        4   944
# 11    assessment concluded        3  1055
# 12  consultation_initiated        3  1084
# 13    assessment initiated        4  1089
# 14                 arrived        5  1139
# 15    assessment concluded        4  1244
# 16    assessment initiated        5  1267
# 17  consultation_initiated        4  1294
# 18    assessment concluded        5  1351
# 19  consultation_initiated        5  1378

# %%
summary.corr()['duration']
# Out:
# Unnamed: 0                -0.043085
# arrival_time              -0.034497
# assessment_end_time       -0.066131
# assessment_start_time     -0.065776
# consultation_end_time      0.038430
# consultation_start_time   -0.066377
# day                       -0.044200
# duration                   1.000000
# patient                   -0.044809
# temperature                0.298949
# Name: duration, dtype: float64

# %%
sns.pairplot(summary);

# %%
summary.loc[summary['temperature'] <= 36.20, 'pain'].value_counts(normalize=True)
# Out:
# severe pain      0.950495
# moderate pain    0.039604
# no pain          0.009901
# Name: pain, dtype: float64

# %%
summary.loc[summary['temperature'] <= 36.20, 'priority'].value_counts(normalize=True)
# Out:
# urgent    1.0
# Name: priority, dtype: float64

# %%
sns.pairplot(day1);

# %%
print(summary.shape)
print(len(summary['Unnamed: 0'].unique()))
print(len(summary['patient'].unique()))
# Out:
# (4420, 12)
# 4420
# 4420

# %%
summary.head(20)
# Out:
#     Unnamed: 0  arrival_time  assessment_end_time  assessment_start_time  \
# 0            1           280                  741                    308
# 1            2           288                  851                    764
# 2            0           430                 1055                    878
# 3            3           944                 1244                   1089
# 4           11          1139                 1351                   1267
# 5            9          1773                 1923                   1811
# 6            5          1798                 2042                   1948
# 7            4          2099                 2248                   2139
# 8            8          2173                 2405                   2280
# 9            6          2199                 2502                   2435
# 10           7          2216                 2625                   2517
# 11          10          2217                 2769                   2643
# 12          15          2245                 2938                   2791
# 13          12          2402                 3144                   2967
# 14          13          2661                 3293                   3214
# 15          14          3170                 3523                   3355
# 16          16          3177                 3663                   3568
# 17          22          3213                 3781                   3704
# 18          20          3280                 3902                   3815
# 19          17          3680                 4067                   3936
#
#     consultation_end_time  consultation_start_time  day  duration  \
# 0                    1620                      773    1       847
# 1                    1881                      905    1       976
# 2                    1595                     1084    1       510
# 3                    2105                     1294    1       810
# 4                    3322                     1378    1      1943
# 5                    3141                     1946    1      1195
# 6                    2763                     2065    1       697
# 7                    2717                     2289    1       427
# 8                    3083                     2434    1       648
# 9                    2791                     2524    1       266
# 10                   3022                     2744    1       277
# 11                   3224                     2798    1       425
# 12                   3987                     2960    1      1026
# 13                   3559                     3171    1       387
# 14                   3651                     3313    1       337
# 15                   3900                     3562    1       337
# 16                   4256                     3697    1       559
# 17                   5242                     3813    1      1429
# 18                   5138                     3939    1      1199
# 19                   4389                     4085    1       303
#
#              pain  patient priority  temperature
# 0         no pain        1   urgent         36.6
# 1     severe pain        2   normal         36.7
# 2     severe pain        3   normal         36.8
# 3     severe pain        4   urgent         36.6
# 4     severe pain        5   urgent         36.2
# 5   moderate pain        6   normal         36.4
# 6         no pain        7   urgent         37.2
# 7         no pain        8   normal         36.7
# 8   moderate pain        9   normal         36.6
# 9   moderate pain       10   normal         36.8
# 10        no pain       11   normal         36.8
# 11        no pain       12   normal         36.9
# 12  moderate pain       13   normal         36.7
# 13        no pain       14   normal         36.6
# 14        no pain       15   normal         36.8
# 15        no pain       16   normal         36.6
# 16  moderate pain       17   urgent         36.8
# 17    severe pain       18   urgent         37.8
# 18        no pain       19   normal         36.8
# 19        no pain       20   normal         36.8

# %%
sns.scatterplot('patient', 'arrival_time', data=summary, hue='day');

# %%
summary.loc[summary['day'] == 50, 'arrival_time'].corr(summary.loc[summary['day'] == 50, 'patient'])
# Out:
# 0.9953782079689507

# %%
df = summary.sort_values(['day', 'arrival_time'])

# %%
sns.distplot(df['duration']);

# %%
sns.distplot(np.log(df['duration']));

# %%
df['log_consult_duration'] = np.log(df['duration'])

# %%
df['pain'].value_counts()
# Out:
# no pain          2709
# moderate pain     968
# severe pain       743
# Name: pain, dtype: int64

# %%
pain_map = {'no pain': 0, 'moderate pain': 1, 'severe pain': 2}
df['pain_enc'] = df['pain'].map(pain_map)
df['pain_enc'].value_counts()
# Out:
# 0    2709
# 1     968
# 2     743
# Name: pain_enc, dtype: int64

# %%
df['priority'].value_counts()
# Out:
# normal    3154
# urgent    1266
# Name: priority, dtype: int64

# %%
priority_map = {'normal': 0, 'urgent': 1}
df['priority_enc'] = df['priority'].map(priority_map)
df['priority_enc'].value_counts()
# Out:
# 0    3154
# 1    1266
# Name: priority_enc, dtype: int64

# %%
df['assessment_duration'] = df['assessment_end_time'] - df['assessment_start_time']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4420 entries, 0 to 4419
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               4420 non-null   int64
#  1   arrival_time             4420 non-null   int64
#  2   assessment_end_time      4420 non-null   int64
#  3   assessment_start_time    4420 non-null   int64
#  4   consultation_end_time    4420 non-null   int64
#  5   consultation_start_time  4420 non-null   int64
#  6   day                      4420 non-null   int64
#  7   duration                 4420 non-null   int64
#  8   pain                     4420 non-null   object
#  9   patient                  4420 non-null   int64
#  10  priority                 4420 non-null   object
#  11  temperature              4420 non-null   float64
#  12  log_consult_duration     4420 non-null   float64
#  13  pain_enc                 4420 non-null   int64
#  14  priority_enc             4420 non-null   int64
#  15  assessment_duration      4420 non-null   int64
# dtypes: float64(2), int64(12), object(2)
# memory usage: 587.0+ KB

# %%
cols_to_drop = ['Unnamed: 0', 'assessment_end_time', 'consultation_end_time',
                'duration', 'pain', 'patient', 'priority']
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4420 entries, 0 to 4419
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   arrival_time             4420 non-null   int64
#  1   assessment_start_time    4420 non-null   int64
#  2   consultation_start_time  4420 non-null   int64
#  3   day                      4420 non-null   int64
#  4   temperature              4420 non-null   float64
#  5   log_consult_duration     4420 non-null   float64
#  6   pain_enc                 4420 non-null   int64
#  7   priority_enc             4420 non-null   int64
#  8   assessment_duration      4420 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 345.3 KB

# %%
sns.pairplot(df);

# %%
X_train = df[df['day'] <= 45].drop(['day', 'log_consult_duration'], axis=1)
X_test = df[df['day'] > 45].drop(['day', 'log_consult_duration'], axis=1)
y_train = df.loc[df['day'] <= 45, 'log_consult_duration']
y_test = df.loc[df['day'] > 45, 'log_consult_duration']

# %%
tscv = TimeSeriesSplit(n_splits=5)

elnet = ElasticNet(normalize=True, random_state=42)

elnet_params ={'alpha': ss.uniform(-1, 1),
               'l1_ratio': ss.uniform(0, 1)}

rscv = RandomizedSearchCV(elnet,
                          elnet_params,
                          n_iter=1000,
                          scoring='neg_root_mean_squared_error',
                          n_jobs=-1,
                          cv=tscv,
                          verbose=1,
                          random_state=42,
                          return_train_score=True)

rscv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 4930 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 5000 out of 5000 | elapsed:   17.9s finished
# /home/jeffc/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# /home/jeffc/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2872.443227711822, tolerance: 0.14371954865209136
#   positive)
# RandomizedSearchCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=5),
#                    error_score=nan,
#                    estimator=ElasticNet(alpha=1.0, copy_X=True,
#                                         fit_intercept=True, l1_ratio=0.5,
#                                         max_iter=1000, normalize=True,
#                                         positive=False, precompute=False,
#                                         random_state=42, selection='cyclic',
#                                         tol=0.0001, warm_start=False),
#                    iid='deprecated', n_iter=1000, n_jobs=-1,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f58a1020850>,
#                                         'l1_ratio': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f58a1606a10>},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=1)

# %%
lm = rscv.best_estimator_
lm
# Out:
# ElasticNet(alpha=-0.8042220143164539, copy_X=True, fit_intercept=True,
#            l1_ratio=0.00756287497814212, max_iter=1000, normalize=True,
#            positive=False, precompute=False, random_state=42,
#            selection='cyclic', tol=0.0001, warm_start=False)

# %%
cv_results = pd.DataFrame(rscv.cv_results_)
train_rmse = -cv_results.loc[rscv.best_index_, 'mean_train_score']
val_rmse = -cv_results.loc[rscv.best_index_, 'mean_test_score']

test_rmse = mean_squared_error(y_test, lm.predict(X_test))

print(f'train rmse: {train_rmse}')
print(f'val rmse: {val_rmse}')
print(f'test rmse: {test_rmse}')
# Out:
# train rmse: 0.5676473924509107
# val rmse: 0.6156629871202328
# test rmse: 0.37244959186368076
